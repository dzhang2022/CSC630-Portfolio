# %%
import numpy as np
import matplotlib.pyplot as plt

years = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
subscribers = [9.16, 11.89, 18.26, 24.30, 30.36, 41.43, 54.47, 70.83, 89.09, 110.64, 139.25, 167.09, 203.66]

plt.scatter(years, subscribers)
plt.plot(years, subscribers)
plt.title("Netflix Subscribers per Year since 2008")
plt.ylabel("Subscribers in Millions")
# Out:
# Text(0, 0.5, 'Subscribers in Millions')
